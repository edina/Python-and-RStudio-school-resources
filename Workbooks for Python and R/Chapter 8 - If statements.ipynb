# %% [markdown]
# ![image](https://raw.githubusercontent.com/willtheorangeguy/Python-Logo-Widgets/master/pythonlogogif.gif?raw=true)

# %% [markdown]
# # If statements - Chapter 8

# %% [markdown]
# # Recap

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
# Last time you looked at Maths. You:
#
# * Learnt the symbols for maths operations in Python
# * Used the **int** function to convert input to an integer
# * Used the **float** function to convert input to a real number with a decimal point
# * Wrote code to define variables and perform calculations e.g. adding together three variables
# * Used the **print** function to display results
#
# </div>

# %% [markdown]
# # Learning Objectives

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
#  By the end of this chapter you will:
#
# * Understand the significance of indented code - code that is related to the statement above it
# * Write code with **If statements** that specifies what action to take if a condition is true
# * Use **Else/if** statements to specify what action to take if a condition is true OR false

# %% [markdown]
# ## Legend for colours

# %% [markdown]
# <div class = "alert alert-block alert-success">
# In <b> green, information and code examples </b> are highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-info">
# In <b> blue, YouTube tutorials </b> are highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# In <b> yellow, activities </b> are highlighted.
# </div>

# %% [markdown]
# # Conditions

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
# In programming, we often ask yes or no questions, and decide to do something based on the answer. For example, we might ask, “Are you older than 20?” and if the answer is yes, respond with, “You are too old!” These sorts of questions are called conditions, and we combine these conditions and the responses into if-statements.
#
# ## For example:
#
#     if age > 20:
#         print('You are too old!')
#
# The code above will check to see if the user’s age is greater than 20. If it is, it will print the message, ‘You are too old!’ If younger than 20 though, then it won’t print that message.

# %% [markdown]
# # If/Else Statements

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
# In addition to using If statements to do something when a condition is met (True), we can also use If statements to do something when a condition is not met (False). This logic essentially says, “if something is true, then do this; or else, do that.”
# For example, we might ask, “Are you older than 20?” If the answer is yes, respond with, “You are too old!” If the answer is no, respond with, “You are awesome!” We simply use the word ‘else’ to tell the computer what else it has to do if the original condition is not met.
#
#
# ## For example:
#
#     if age > 20:
#         print('You are too old!')
#     else:
#         print('You are awesome!)
#
# The code above will check to see if the user’s age is greater than 20. If it is, it will print the message, ‘You are too old!’ If younger than 20 though, it will print the message, ‘You are awesome!’

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# ## Video tutorial
#
# ### If/Else Statements - Is it Sunny?:
#
# The video should appear below - if not select this link to view it in a new browser window: https://www.youtube.com/watch?v=P5JX8jpNd0w
# </div>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('P5JX8jpNd0w', width=800, height=300)

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# ## Video tutorial
#
# ### If/Else Statements 2 - Can you ride?:
#
# The video should appear below - if not select this link to view it in a new browser window: https://www.youtube.com/watch?v=uHXxc9YEn54
# </div>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('uHXxc9YEn54', width=800, height=300)

# %% [markdown]
# # ELIF Statements

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
#    We can extend an if-statement even further with elif (which is short for else-if). It allows us to check multiple conditions.
#
# ## Look at this code example:
#     if age > 20:
#         print('You are too old')
#     elif age > 10:
#         print('You are awesome!)
#     else:
#         print('You are too young')
#
# The above code will check to see if the user’s age is greater than 20. If it is, it will print the message, ‘You are too old!’ If it’s less than 20 but still greater than 10, it will print the message, ‘You are awesome!’ If the age is any thing else (less than 10), it will print the message ‘You are too young.’
#
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# ## Video tutorial
#
# ### Elif Statements 1 - Movie Classifications:
#
# The video should appear below - if not select this link to view it in a new browser window: https://www.youtube.com/watch?v=D6C8Qu1Wi34
# </div>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('D6C8Qu1Wi34', width=800, height=300)

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# ## Video tutorial
#
# ### Elif Statements 2 - Legal Age Limit:
#
# The video should appear below - if not select this link to view it in a new browser window: https://www.youtube.com/watch?v=0l1Uyf0db7g
#
# </div>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('0l1Uyf0db7g', width=800, height=300)

# %% [markdown]
# # Indentation

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
# You might have noticed that in the examples above, certain sections of code have been indented – that’s the empty white space at the start of a line of code. In Python, whitespace (such as these indents) is meaningful. Indented code is known as a block of code. Indented code will always be connected to a statement above it.
#
# In the examples above, the indented code will only be run if the statement directly above it is true. If the condition is true, then it will run the next line of indented code below it. If the statement is false, then the compiler will ignore and skip straight past that indented code directly below it.
#
#
# </div>

# %% [markdown]
# # Activities

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 14
#
# 1. Create a new code cell.
# 2. Write a program that asks the user if Canberra is the capital city of Australia. If the user answers ‘yes’ then tell them that they are correct. If they answer with anything else, tell them that they have answered incorrectly.
#
#
# # Steps
#
# 1. Select **Insert** and **Insert cell below**.
# 2. Set cell type as **Code**.
# 3. Type:
#         aus_capital = input('What is the capital of Australia? ')
#         if aus_capital == 'Canberra':
#             print('You are correct!')
#         else:
#             print('Sorry, try again!')
#
#
# 4. Select **Run**.
#
#     </div>

# %%
# Example for teacher use

aus_capital = input('What is the capital of Australia? ')
if aus_capital == 'Canberra':  
     print('You are correct!')  
else:     
     print('Sorry, try again!')

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 15
#
#
# 1. Draw a flowchart on https://www.draw.io/ for a program that asks a user to enter their exam result (as a number out of 100). If the student obtained 50% or higher, then display a message telling them that they’ve passed. Otherwise, tell the student that they have failed.
# 2. Export this flowchart as 15_exam_result.png
# 2. Once your flowchart is drawn, write the program in Python in a new code cell below.
#
#
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 16
#
# 1. Add a new code cell below.
# 2. Write a program that asks the user how many hours they spend on their phone per day.
# * IF it is less than 1 hour, the program says, “That seems reasonable."
# * ELSE IF it is between 1 and 3 hours per day it says, “It sounds like you're developing an addiction.”
# * Anything ELSE, the program says, “You need to get a life!”
#
#
#
#
# # Steps
#
# 1. Select **Insert** and **Insert cell below**.
# 2. Set cell type as **Code**.
# 3. Type:
#
#            time = float(input("How many hours do you spend on your phone each day?: "))
#            if time < 1:
#                 print("That seems reasonable")
#             elif 1 <= time <= 3:
#                 print("It sounds like you're decveloping an addiction.")
#             else:
#                 print("You need to get a life!")
#
# 4. Select **Run**.
#
#     </div>

# %%
# Example for teacher use
time = float(input("How many hours do you spend on your phone each day?: "))
if time < 1:  
   print("That seems reasonable")  
elif 1 <= time <= 3:
   print("It sounds like you are developing an addiction.")  
else:  
   print("You need to get a life!")

# %% [markdown]
# [![CC BY 4.0][cc-by-shield]][cc-by]
#
# This work is licensed under a
#
# [Creative Commons Attribution 4.0 International License][cc-by].
#
# [![CC BY 4.0][cc-by-image]][cc-by]
#
# To view a copy of this license, visit http://creativecommons.org/licenses/by/4.0/ or send a letter to Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.
#
# [cc-by]: http://creativecommons.org/licenses/by/4.0/
#
# [cc-by-image]: https://i.creativecommons.org/l/by/4.0/88x31.png
#
# [cc-by-shield]: https://img.shields.io/badge/License-CC%20BY%204.0-lightgrey.svg

# %% [markdown]
# ![Noteable.ac.uk Banner](https://github.com/jstix/everything-noteable/blob/master/CLPL%20Banner/Header%20for%20Github%20-%20CLPL%20materials%20.png?raw=true)
