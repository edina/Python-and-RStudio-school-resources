# %% [markdown]
# ![image](https://raw.githubusercontent.com/willtheorangeguy/Python-Logo-Widgets/master/pythonlogogif.gif?raw=true)

# %% [markdown]
# # Inputs and Variables - Chapter 6

# %% [markdown]
# # Recap

# %% [markdown]
# <div class = "alert alert-block alert-success">
# Last time you tried out printing and used the **Print** function:
#
# * Display a single line message on screen
#
# * Display a multiple line message on screen
# </div>

# %% [markdown]
# # Learning Objectives

# %% [markdown]
# <div class = "alert alert-block alert-success">
# In this chapter, we look at inputs and variables. You will:
#
# * Use the **input** function to get information  - a **variable** - from the user
# * Print statements combining variables with pre-defined text
# </div>

# %% [markdown]
# ## Legend for colours

# %% [markdown]
# <div class = "alert alert-block alert-success">
# In <b> green, information </b> is highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-info">
# In <b> blue, YouTube tutorials </b> are highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# In <b> yellow, activities </b> are highlighted.
# </div>

# %% [markdown]
# # The input() function

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
# * The **input** function allows the user to enter information into the computer.
# * The computer can save this information into a variable.
# * A **variable** is used to store information in a program.
#
#
# </div>

# %% [markdown]
# # Variable and input example

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
# Look at this code example:
#
#     name = input("What is your name?")
#
# * The **input** function prints a message on the screen asking a user what their name is.
# * The variable is "name". Whaetever the user types will be stored in the name variable.
#
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# ## Video tutorial
#
# ### Asking questions and storing variables with Python:
#
# The video should appear below - if not select this link to view it in a new browser window: https://www.youtube.com/watch?v=616y2RB1hd8
# </div>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('616y2RB1hd8', width=800, height=300)

# %% [markdown]
# # Create and print a variable

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 6
#
# 1. Create a new code cell.
# 2. Write a program in the code cell that asks a user for their middle name. The program will then display what their middle name is in a full sentence, for example "Your middle name is Anne".
#
#
# # Steps
#
# 1. Select **Insert** and **Insert cell below**.
# 2. Set cell type as **Code**.
# 3. Type:
#
#         name = input(What is your middle name?")
#         print("Your middle name is", name)
#
# 4. Select **Run**.
#
#     </div>

# %%
# Example for teacher use

name = input("what is your middle name?")
print("your middle name is", name)

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 7
#
# Write a code cell that asks a user for their first name. The program will then write out the lyrics to ‘Happy Birthday’ over multiple lines and will include the user’s name in the song.
#
#
#
# **NOTES:**
#
# * Type the words within **3 single quotes.**
# * Select enter where you want a new line.
#
# # Steps
#
# 1. Select **Insert** and **Insert cell below**.
# 2. Set cell type as **Code**.
# 3. Type:
#
#         name = input("What is your name?")
#         print('''Happy birthday to you
#         Happy birthday to you
#         Happy birthday dear''', name, '''
#         Happy birthday to you
#         ''')
#
#
# 4. Select **Run**.
#
#     </div>

# %%
# Example for teacher use

name = input("What is your name?")
print('''Happy birthday to you
Happy birthday to you
Happy birthday dear''', name, '''
Happy birthday to you
''')

# %% [markdown]
# # Create and print multiple variables

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# ## Video tutorial
#
# ### Variables, Comments and Concatenation:
#
# The video should appear below - if not select this link to view it in a new browser window: https://www.youtube.com/watch?v=VzQl5BmvzVE
#
# </div>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('VzQl5BmvzVE', width=800, height=300)

# %% [markdown]
# ## Write a program

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 8
#
# * Create a code cell that asks a user for their name, their favourite colour and their favourite TV show.
# * Display back to the user in a full sentences what their name is, their favourite colour and their favourite TV show.
# * For example: **Hi Bob. Your favourite colour is blue and you like to watch Love Island.**
#
# NOTE: Type your text within double quotation marks. "text..."
#
#
# # Steps
#
# 1. Select **Insert** and **Insert cell below**.
# 2. Set cell type as **Code**.
# 3. Type:
#
#         name = input("What is your name?")
#         colour = input("What is your favourite colour?")
#         tv = input("What is your favourite TV show?")
#         print("Hi", name, "your favourite colour is", colour, "and you like to watch", tv)
#
# 4. Select **Run**.
#
#     </div>

# %%
# Example for teacher use

name = input("What is your name? ")
colour = input("What is your favourite colour? ")
tv = input("What is your favourite TV show? ")  
print("Hi", name, "your favourite colour is", colour, "and you like to watch", tv)

# %% [markdown]
# [![CC BY 4.0][cc-by-shield]][cc-by]
#
# This work is licensed under a
#
# [Creative Commons Attribution 4.0 International License][cc-by].
#
# [![CC BY 4.0][cc-by-image]][cc-by]
#
# To view a copy of this license, visit http://creativecommons.org/licenses/by/4.0/ or send a letter to Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.
#
# [cc-by]: http://creativecommons.org/licenses/by/4.0/
#
# [cc-by-image]: https://i.creativecommons.org/l/by/4.0/88x31.png
#
# [cc-by-shield]: https://img.shields.io/badge/License-CC%20BY%204.0-lightgrey.svg

# %% [markdown]
# ![Noteable.ac.uk Banner](https://github.com/jstix/everything-noteable/blob/master/CLPL%20Banner/Header%20for%20Github%20-%20CLPL%20materials%20.png?raw=true)
