# %% [markdown]
# ![image](https://raw.githubusercontent.com/willtheorangeguy/Python-Logo-Widgets/master/pythonlogogif.gif?raw=true)

# %% [markdown]
# # The Print function - Chapter 5

# %% [markdown]
#  # Recap

# %% [markdown]
# <div class = "alert alert-block alert-success">
# Last time, we looked at:
#
# * Sequence - code is run in sequence, one line at a time, until the end of the program
# * Selection - If statements are used to select and run only the required lines of code
# * Iteration - loops can be used to iterate lines of code
# </div>

# %% [markdown]
# # Learning Objectives

# %% [markdown]
# <div class = "alert alert-block alert-success">
# By the end of this chapter, you will be able to use the Print function to:
#
# * Display a single line message on screen
#
# * Display a multiple line message on screen
# </div>

# %% [markdown]
# ## Legend for colours

# %% [markdown]
# <div class = "alert alert-block alert-success">
# In <b> green, information and code examples </b> are highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-info">
# In blue, <b> YouTube tutorials </b> are highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# In <b> yellow, activities </b> are highlighted.
# </div>

# %% [markdown]
# # Display information on screen

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
# The **Print** function is used to display information on the screen.
#
#
# The code shown in the image below will display the words “Hello World” on the screen.
#
#
# You can also print messages that span across multiple lines - for example see the image below which displays the words over 3 lines.
#
#
# </div>

# %% [markdown]
# # Watch a video

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# ## Video tutorial
#
# ### Display messages:
#
# The video should appear below - if not select this link to view it in a new browser window: https://youtu.be/9jY-Jz1pqrA
# </div>

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('9jY-Jz1pqrA', width=800, height=300)

# %% [markdown]
# # Print your full name

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 3
# Create a code cell that writes your full name on the screen, similar to the example below.
#
# NOTE: Type your text within double quotation marks. ""
#
# ## Example
#     print("My full name is John Bob Smith.")
#
# # Steps
#
# 1. Select **Insert** and **Insert cell below**.
# 2. Set cell type as **Code**.
# 3. Type:
#          print("My full name is...")
#
# 4. Select **Run**.
#
#     </div>

# %%
# Example for teacher use

print("My full name is Bart Simpson.")
# Out:
# My full name is Bart Simpson.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# ## Video tutorial
#
# ### Display multi-line messages:
#
# The video should appear below - if not select this link to view it in a new browser window: https://youtu.be/03uLv5bk0ik
# </div>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('03uLv5bk0ik', width=800, height=300)

# %% [markdown]
# # Print multiple lines

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 4
#
# Write a code cell that displays a quick joke over 2 lines, similar to that shown in the image below.
#
# NOTE: Type your joke within **3 single quotation marks.** Select enter where you want the new line.
#
# # Steps
#
# 1. Select **Insert** and **Insert cell below**.
# 2. Set cell type as **Code**.
# 3. Type:
#         print('''Why did the chicken cross the road?
#         To get to the other side!''')
#
#
# 4. Select **Run**.
#
#     </div>

# %%
# Example for teacher use

print('''Why did the chicken cross the road? 
To get to the other side!''')
# Out:
# Why did the chicken cross the road?
# To get to the other side!

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# # Activity 5
#
# Write a code cell that displays the following multi-line message, similar to that shown in the image below.
#
#
# KEEP
# CALM
# and
# CODE
# PYTHON
#
# **NOTES:**
#
# * Type the words within **3 single quotes.**
# * Select enter where you want a new line.
#
# # Steps
#
# 1. Select **Insert** and **Insert cell below**.
# 2. Set cell type as **Code**.
# 3. Type:
#         print('''KEEP
#         CALM
#         and
#         CODE
#         PYTHON''')
#
# 4. Select **Run**.
#
#     </div>

# %%
# Example for teacher use

print('''KEEP  
CALM  
and  
CODE  
PYTHON''')
# Out:
# KEEP
# CALM
# and
# CODE
# PYTHON

# %% [markdown]
# [![CC BY 4.0][cc-by-shield]][cc-by]
#
# This work is licensed under a
#
# [Creative Commons Attribution 4.0 International License][cc-by].
#
# [![CC BY 4.0][cc-by-image]][cc-by]
#
# To view a copy of this license, visit http://creativecommons.org/licenses/by/4.0/ or send a letter to Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.
#
# [cc-by]: http://creativecommons.org/licenses/by/4.0/
#
# [cc-by-image]: https://i.creativecommons.org/l/by/4.0/88x31.png
#
# [cc-by-shield]: https://img.shields.io/badge/License-CC%20BY%204.0-lightgrey.svg

# %% [markdown]
# ![Noteable.ac.uk Banner](https://github.com/jstix/everything-noteable/blob/master/CLPL%20Banner/Header%20for%20Github%20-%20CLPL%20materials%20.png?raw=true)
